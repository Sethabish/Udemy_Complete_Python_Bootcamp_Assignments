# %% [markdown]
# <img src='Pierian_Data_Logo.png'/>

# %% [markdown]
# # Milestone Project 1 - Tic Tac Toe

# %%
def display(row1,row2,row3):
    print('    1   2   3')
    print('  -------------')
    print('1 | {} | {} | {} |'.format(row1[0],row1[1],row1[2]))
    print('  -------------')
    print('2 | {} | {} | {} |'.format(row2[0],row2[1],row2[2]))
    print('  -------------')
    print('3 | {} | {} | {} |'.format(row3[0],row3[1],row3[2]))
    print('  -------------')

# %%
def x_o(list_x_o):
    if list_x_o[-1] == 'o':
        in_put = input('Player "X" turn: ')
        if in_put == 'x':
            return in_put
        else:
            return 'Wrong Input'
    else:
        in_put = input('Player "O" turn: ')
        if in_put == 'o':
            return in_put
        else:
            return 'Wrong Input'

# %%
def choose_block(block_choice,in_put,row_in,list_x_o,row1,row2,row3):
    if block_choice in ['11','12','13','21','22','23','31','32','33']:
            if block_choice in row_in:
                print('Block already filled, try another...')
            else:
                if in_put in 'xo':
                    row_in.append(block_choice)
                    list_x_o.append(in_put)
                    if block_choice[0] == '1':
                        row1[int(block_choice[1])-1] = in_put.upper()
                    elif block_choice[0] == '2':
                        row2[int(block_choice[1])-1] = in_put.upper()
                    elif block_choice[0] == '3':
                        row3[int(block_choice[1])-1] = in_put.upper()
                else:
                    print('Wrong input')
                display(row1,row2,row3)
    else:
        print('Wrong block choice try again')

# %%
def win_check(row1,row2,row3):
    if (row1[0] == 'O' and row1[1] == 'O' and row1[2] == 'O') or \
    (row2[0] == 'O' and row2[1] == 'O' and row2[2] == 'O') or \
    (row3[0] == 'O' and row3[1] == 'O' and row3[2] == 'O') or \
    (row1[0] == 'O' and row2[0] == 'O' and row3[0] == 'O') or \
    (row1[1] == 'O' and row2[1] == 'O' and row3[1] == 'O') or \
    (row1[2] == 'O' and row2[2] == 'O' and row3[2] == 'O') or \
    (row1[0] == 'O' and row2[1] == 'O' and row3[2] == 'O') or \
    (row1[2] == 'O' and row2[1] == 'O' and row3[0] == 'O'):
        return '*** PLAYER "O" WON ***'
    elif (row1[0] == 'X' and row1[1] == 'X' and row1[2] == 'X') or \
    (row2[0] == 'X' and row2[1] == 'X' and row2[2] == 'X') or \
    (row3[0] == 'X' and row3[1] == 'X' and row3[2] == 'X') or \
    (row1[0] == 'X' and row2[0] == 'X' and row3[0] == 'X') or \
    (row1[1] == 'X' and row2[1] == 'X' and row3[1] == 'X') or \
    (row1[2] == 'X' and row2[2] == 'X' and row3[2] == 'X') or \
    (row1[0] == 'X' and row2[1] == 'X' and row3[2] == 'X') or \
    (row1[2] == 'X' and row2[1] == 'X' and row3[0] == 'X'):
        return '*** PLAYER "X" WON ***'
    else:
        pass

# %%
def restart():
    in_put = input('Do you want to play again (y or n): ')
    if in_put == 'y':
        return tic_tac_toe()
    elif in_put == 'n':
        return '*** GAME OVER ***'
    else:
        print('Wrong Input')
        return '*** GAME OVER ***'

# %%
def tic_tac_toe():
    row1=[' ',' ',' ']
    row2=[' ',' ',' ']
    row3=[' ',' ',' ']
    row_in,list_x_o=[],['o']
    print('*** Welcome to TIC TAC TOE ***')
    display(row1,row2,row3)
    while len(list_x_o)<10:
        in_put = x_o(list_x_o)
        if in_put == 'Wrong Input':
            print(in_put)
            continue
        block_choice = input('Enter the block choice: ')
        choose_block(block_choice,in_put,row_in,list_x_o,row1,row2,row3)
        if len(list_x_o)-1<=9:
            if win_check(row1,row2,row3) == '*** PLAYER "X" WON ***' or \
            win_check(row1,row2,row3) == '*** PLAYER "O" WON ***':
                print(win_check(row1,row2,row3))
                return restart()
    else:
        print('*** DRAW ***')
        return restart()

# %%
tic_tac_toe()
# Out:
# *** Welcome to TIC TAC TOE ***
#     1   2   3
#   -------------
# 1 |   |   |   |
#   -------------
# 2 |   |   |   |
#   -------------
# 3 |   |   |   |
#   -------------
# Player "X" turn: x
# Enter the block choice: 33
#     1   2   3
#   -------------
# 1 |   |   |   |
#   -------------
# 2 |   |   |   |
#   -------------
# 3 |   |   | X |
#   -------------
# Player "O" turn: x
# Wrong Input
# Player "O" turn: o
# Enter the block choice: 22
#     1   2   3
#   -------------
# 1 |   |   |   |
#   -------------
# 2 |   | O |   |
#   -------------
# 3 |   |   | X |
#   -------------
# Player "X" turn: x
# Enter the block choice: 33
# Block already filled, try another...
# Player "X" turn: x
# Enter the block choice: 13
#     1   2   3
#   -------------
# 1 |   |   | X |
#   -------------
# 2 |   | O |   |
#   -------------
# 3 |   |   | X |
#   -------------
# Player "O" turn: o
# Enter the block choice: 34
# Wrong block choice try again
# Player "O" turn: o
# Enter the block choice: 23
#     1   2   3
#   -------------
# 1 |   |   | X |
#   -------------
# 2 |   | O | O |
#   -------------
# 3 |   |   | X |
#   -------------
# Player "X" turn: x
# Enter the block choice: 21
#     1   2   3
#   -------------
# 1 |   |   | X |
#   -------------
# 2 | X | O | O |
#   -------------
# 3 |   |   | X |
#   -------------
# Player "O" turn: o
# Enter the block choice: 12
#     1   2   3
#   -------------
# 1 |   | O | X |
#   -------------
# 2 | X | O | O |
#   -------------
# 3 |   |   | X |
#   -------------
# Player "X" turn: x
# Enter the block choice: 32
#     1   2   3
#   -------------
# 1 |   | O | X |
#   -------------
# 2 | X | O | O |
#   -------------
# 3 |   | X | X |
#   -------------
# Player "O" turn: o
# Enter the block choice: 31
#     1   2   3
#   -------------
# 1 |   | O | X |
#   -------------
# 2 | X | O | O |
#   -------------
# 3 | O | X | X |
#   -------------
# Player "X" turn: x
# Enter the block choice: 11
#     1   2   3
#   -------------
# 1 | X | O | X |
#   -------------
# 2 | X | O | O |
#   -------------
# 3 | O | X | X |
#   -------------
# *** DRAW ***
# Do you want to play again (y or n): n
# '*** GAME OVER ***'
